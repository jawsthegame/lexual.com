# %% [markdown]
# [ipynb](https://github.com/lexual/lexual.com/blob/master/content/blog/tech/2012-03-18_test-ipython-notebook.ipynb)
#
# [nbviewer](http://nbviewer.ipython.org/urls/github.com/lexual/lexual.com/raw/master/content/blog/tech/2012-03-18_test-ipython-notebook.ipynb)

# %%
sum(x for x in xrange(100))
# Out:
# 4950

# %%
import pandas as pd
s = pd.Series(xrange(20))
s.plot()

# %%
pd.Series(np.sin(arange(0, np.pi*4, .01))).plot()
